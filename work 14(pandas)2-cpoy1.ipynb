# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bd=pd.read_csv('E:\\python work deep\\BollywoodMovieDetail.csv',parse_dates=['releaseDate'])

# %%
bd
# Out:
#          imdbId                                title  releaseYear releaseDate  \
# 0     tt0118578                               Albela         2001  2001-04-20
# 1     tt0169102    Lagaan: Once Upon a Time in India         2001  2002-05-08
# 2     tt0187279             Meri Biwi Ka Jawab Nahin         2004  2004-07-02
# 3     tt0222024               Hum Tumhare Hain Sanam         2002  2002-05-24
# 4     tt0227194                           One 2 Ka 4         2001  2001-03-30
# 5     tt0238936                               Devdas         2002  2002-07-12
# 6     tt0247911          Aap Mujhe Achche Lagne Lage         2002  2002-04-19
# 7     tt0248126          Kabhi Khushi Kabhie Gham...         2001  2001-12-14
# 8     tt0248216                  Na Tum Jaano Na Hum         2002  2002-05-10
# 9     tt0248617                           Yaadein...         2001  2001-06-27
# 10    tt0255713                             Zubeidaa         2001  2001-01-19
# ...

# %%
bd.head(20)
# Out:
#        imdbId                              title  releaseYear releaseDate  \
# 0   tt0118578                             Albela         2001  2001-04-20
# 1   tt0169102  Lagaan: Once Upon a Time in India         2001  2002-05-08
# 2   tt0187279           Meri Biwi Ka Jawab Nahin         2004  2004-07-02
# 3   tt0222024             Hum Tumhare Hain Sanam         2002  2002-05-24
# 4   tt0227194                         One 2 Ka 4         2001  2001-03-30
# 5   tt0238936                             Devdas         2002  2002-07-12
# 6   tt0247911        Aap Mujhe Achche Lagne Lage         2002  2002-04-19
# 7   tt0248126        Kabhi Khushi Kabhie Gham...         2001  2001-12-14
# 8   tt0248216                Na Tum Jaano Na Hum         2002  2002-05-10
# 9   tt0248617                         Yaadein...         2001  2001-06-27
# 10  tt0255713                           Zubeidaa         2001  2001-01-19
# 11  tt0256692          Chori Chori Chupke Chupke         2001  2001-03-09
# ...

# %%
titleyear=bd['title']
genre=bd['genre']
tname = []
for z in range(len(titleyear)):
    tname.append(titleyear[z])
gname=[]
for z in range(len(genre)):
    gname.append(genre[z])
dic = {
    'title':tname,
    'genre':gname
}
print(len(tname))
new = pd.DataFrame(dic)
new
# Out:
# 1284
#                                     title                          genre
# 0                                  Albela                        Romance
# 1       Lagaan: Once Upon a Time in India    Adventure | Drama | Musical
# 2                Meri Biwi Ka Jawab Nahin                Action | Comedy
# 3                  Hum Tumhare Hain Sanam                Drama | Romance
# 4                              One 2 Ka 4        Action | Comedy | Drama
# 5                                  Devdas              Musical | Romance
# 6             Aap Mujhe Achche Lagne Lage       Action | Drama | Romance
# 7             Kabhi Khushi Kabhie Gham...      Drama | Musical | Romance
# 8                     Na Tum Jaano Na Hum       Comedy | Drama | Musical
# 9                              Yaadein...      Musical | Drama | Romance
# 10                               Zubeidaa  Adventure | Biography | Drama
# 11              Chori Chori Chupke Chupke      Drama | Musical | Romance
# ...

# %%
new.fillna({'title':'unknown',
           'genre': 'not avaliable'})
# Out:
#                                     title                          genre
# 0                                  Albela                        Romance
# 1       Lagaan: Once Upon a Time in India    Adventure | Drama | Musical
# 2                Meri Biwi Ka Jawab Nahin                Action | Comedy
# 3                  Hum Tumhare Hain Sanam                Drama | Romance
# 4                              One 2 Ka 4        Action | Comedy | Drama
# 5                                  Devdas              Musical | Romance
# 6             Aap Mujhe Achche Lagne Lage       Action | Drama | Romance
# 7             Kabhi Khushi Kabhie Gham...      Drama | Musical | Romance
# 8                     Na Tum Jaano Na Hum       Comedy | Drama | Musical
# 9                              Yaadein...      Musical | Drama | Romance
# 10                               Zubeidaa  Adventure | Biography | Drama
# 11              Chori Chori Chupke Chupke      Drama | Musical | Romance
# ...

# %%
new.dropna()

# %%
new.to_excel('title and genre.xlsx')

# %%
import pandas as pd
import numpy as np
ex=pd.read_excel('E:\\Book1.xlsx',na_values=['na'],parse_dates=['date'])
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-3-9b9162ff0342> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 ex=pd.read_excel('E:\\Book1.xlsx',na_values=['na'],parse_dates=['date'])
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ...

# %%
ex
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8d9a7e549514> in <module>()
# ----> 1 ex
#
# NameError: name 'ex' is not defined

# %%
type(ex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-92364334d5ba> in <module>()
# ----> 1 type(ex)
#
# NameError: name 'ex' is not defined

# %%
ex['date'][1].weekday_name

# %%
ex.parse_dates=['date']

# %%
ex['date'][1].weekday_name

# %%
ex.replace([np.nan,'n.a','n.a.'],'unknown')

# %%
type(ex['date'][1])

# %%
en=ex['ename']

# %%
concat=pd.concat([ex,en])
concat

# %%
bmovieyear=bd.groupby('releaseYear')

# %%
rec1=bmovieyear.get_group(2001)

# %%
rec1
# Out:
#         imdbId                                title  releaseYear releaseDate  \
# 0    tt0118578                               Albela         2001  2001-04-20
# 1    tt0169102    Lagaan: Once Upon a Time in India         2001  2002-05-08
# 4    tt0227194                           One 2 Ka 4         2001  2001-03-30
# 7    tt0248126          Kabhi Khushi Kabhie Gham...         2001  2001-12-14
# 9    tt0248617                           Yaadein...         2001  2001-06-27
# 10   tt0255713                             Zubeidaa         2001  2001-01-19
# 11   tt0256692            Chori Chori Chupke Chupke         2001  2001-03-09
# 13   tt0265452                              Officer         2001  2001-03-14
# 14   tt0267363                          Chandni Bar         2001  2001-09-28
# 15   tt0271604              Kuch Khatti Kuch Meethi         2001  2001-01-19
# 16   tt0272543                               Censor         2001  2001-02-14
# ...

# %%
mer=pd.merge(ex,rec1,how='outer')
mer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3b3aadab1678> in <module>()
# ----> 1 mer=pd.merge(ex,rec1,how='outer')
#       2 mer
#
# NameError: name 'ex' is not defined

# %%
list1=[]
temp=0
for z in range(1,11):
    for i in range(len(bd)):
        if bd['hitFlop'][i]==z:
            temp+=1
    list1.append(temp)
    temp=0

# %%
x=list(range(1,11))
plt.bar(x,list1,color='orange')
plt.title('hitFlop analysis')
plt.xlabel('no. of movies')
plt.ylabel('score')
plt.show()

# %%
list2=[]
temp2=0
for z in range(2001,2014):
    for i in range(len(bd)):
        if bd['releaseYear'][i]==z:
            temp2+=1
    list2.append(temp2)
    temp2=0

# %%
x=list(range(2001,2014))
plt.bar(x,list2,color='orange')
plt.title('hitFlop analysis')
plt.xlabel('Year of release')
plt.ylabel('no. of movies')
plt.show()

# %%
genre=bd['genre']
genre
# Out:
# nan

# %%
list2
# Out:
# [62, 79, 95, 88, 106, 60, 66, 98, 91, 116, 112, 99, 102]

# %%
bd.merge(list2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-be54f33ad886> in <module>()
# ----> 1 bd.merge(list2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6377                      right_on=right_on, left_index=left_index,
#    6378                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6379                      copy=copy, indicator=indicator, validate=validate)
#    6380
#    6381     def round(self, decimals=0, *args, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
directors=bd['directors']
list3=[]
list3.append(directors)
for i in directors:
    if directors=='Sanjay Leela Bhansali':
        print(bd)

# %%
newList=[]
for i in genre[:1260]:
    newList.append(i.split('|'))

# %%
newList
# Out:
# [['Romance'],
#  ['Adventure ', ' Drama ', ' Musical'],
#  ['Action ', ' Comedy'],
#  ['Drama ', ' Romance'],
#  ['Action ', ' Comedy ', ' Drama'],
#  ['Musical ', ' Romance'],
#  ['Action ', ' Drama ', ' Romance'],
#  ['Drama ', ' Musical ', ' Romance'],
#  ['Comedy ', ' Drama ', ' Musical'],
#  ['Musical ', ' Drama ', ' Romance'],
#  ['Adventure ', ' Biography ', ' Drama'],
#  ['Drama ', ' Musical ', ' Romance'],
#  ['Musical ', ' Drama ', ' Romance'],
#  ['Action ', ' Crime ', ' Drama'],
#  ['Crime ', ' Drama'],
#  ['Drama ', ' Family'],
#  ['Musical ', ' Romance'],
#  ['Action'],
#  ['Comedy ', ' Musical ', ' Family'],
#  ['Musical ', ' Romance ', ' Drama'],
#  ['Drama ', ' Family'],
#  ['Action ', ' Comedy ', ' Drama'],
#  ['Drama ', ' Musical ', ' Romance'],
#  ['Romance'],
#  ['Drama ', ' Romance'],
#  ['Drama'],
#  ['Crime ', ' Mystery ', ' Thriller'],
#  ['Comedy'],
#  ['Crime ', ' Drama ', ' Romance'],
#  ['Comedy ', ' Fantasy ', ' Music'],
#  ['Thriller'],
#  ['Romance'],
# ...
